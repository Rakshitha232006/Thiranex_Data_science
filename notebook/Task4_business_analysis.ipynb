# %% [markdown]
# STEP 1 — Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

sns.set(style="whitegrid")

print("Libraries Imported Successfully")

# %% [markdown]
# STEP 2 — Load Cleaned Dataset

# %% [markdown]
# STEP 3 — Dataset Overview

# %% [markdown]
# STEP 4 — Business Analysis
# Movies vs TV Shows

# %% [markdown]
# STEP 5 — Top Producing Countries

# %% [markdown]
# STEP 6 — Content Growth Trend

# %% [markdown]
# STEP 7 — Ratings Distribution

# %% [markdown]
# STEP 8 — Business Insight Dashboard

# %% [markdown]
# STEP 9 — Real-World Machine Learning

# %% [markdown]
# Select Features

# %% [markdown]
# Encode Data

# %% [markdown]
# Define Features & Target

# %% [markdown]
# Train-Test Split

# %% [markdown]
# Train Random Forest Model

# %% [markdown]
# Evaluate Model

# %% [markdown]
# STEP 10 — Feature Importance

# %% [markdown]
# STEP 11 — Business Conclusions

# %% [markdown]
# # Business Conclusions
#
# 1. Netflix contains significantly more Movies than TV Shows.
#
# 2. The USA dominates Netflix content production.
#
# 3. Netflix content rapidly increased after 2015 due to streaming growth.
#
# 4. Mature audience content (TV-MA) is highly dominant.
#
# 5. Machine Learning models can effectively classify Netflix content types.
#
# 6. Data-driven insights can help streaming platforms understand audience trends and content strategies.

# %% [markdown]
# STEP 12 — Save Business Report Data

# %%
df.to_csv(
    "D:/Thiranex/cleaned_data/netflix_business_analysis.csv",
    index=False
)

print("Business Analysis Saved Successfully")
